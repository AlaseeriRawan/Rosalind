# %% [markdown]
# <a href="https://colab.research.google.com/github/AlaseeriRawan/Rosalind/blob/main/7_Counting_Point_Mutations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# DNA1 =
# DNA2 =
# count = 0
# for each 1 substring:
#   if DNA1 =! DNA2:
#      count =+1
# return count

# %%
DNA1 = '...'
DNA2 = '...'
countt = 0
if len(DNA1) != len(DNA2):
  print('length of DNA1 and DNA2 are not the same.')
else:
    for n1, n2 in zip(DNA1, DNA2):
      if n1 != n2:
        countt += 1
    print('count is:')
    print(countt)
# Out:
# count is:
# 449
